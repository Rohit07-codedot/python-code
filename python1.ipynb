# %%
# List example (list can be changed)
a = [1, 2, 3]
a[0] = 10
print(a)
# Out:
# [10, 2, 3]

# %%
# Tuple example (tuple cannot be changed)
b = (1, 2, 3)
b[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Tuple example (tuple cannot be changed)
#       2 b = (1, 2, 3)
# ----> 3 b[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # hello
